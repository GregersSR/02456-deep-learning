# %%
#!pip install scikit-learn pandas numpy torch tqdm matplotlib pyarrow

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from dataloader import load_train, load_val
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
from plot_trajectory import plot_paths
#from metrics import rmse, mse, mae
import joblib
import math

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model: int, max_len: int = 5000):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        pos = torch.arange(0, max_len).unsqueeze(1).float()
        div = torch.exp(torch.arange(0, d_model, 2).float()
                        * (-torch.log(torch.tensor(10000.0)) / d_model))

        pe[:, 0::2] = torch.sin(pos * div)
        pe[:, 1::2] = torch.cos(pos * div)

        pe = pe.unsqueeze(0)     # → [1, max_len, d_model]
        self.register_buffer("pe", pe)

    def forward(self, x):
        """
        x: [batch, seq_len, d_model]
        """
        seq_len = x.size(1)
        return x + self.pe[:, :seq_len, :]


    

class TrajectoryTransformer30to10(nn.Module):
    def __init__(
        self,
        input_dim: int,
        output_dim: int,
        d_model: int = 128,
        nhead: int = 4,
        num_layers: int = 3,
        dim_feedforward: int = 256,
        dropout: float = 0.1,
    ):
        super().__init__()

        self.output_dim = output_dim
        self.future_steps = 10

        self.input_proj = nn.Linear(input_dim, d_model)
        self.pos_enc = PositionalEncoding(d_model)

        enc_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            batch_first=True,              # <-- CHANGED
        )

        self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)

        self.out = nn.Linear(d_model, output_dim * self.future_steps)

    def forward(self, src):
        """
        src: [batch, 30, input_dim]
        return: [batch, 10, output_dim]
        """
        x = self.input_proj(src)       # [B, 30, d_model]
        x = self.pos_enc(x)            # [B, 30, d_model]
        x = self.encoder(x)            # [B, 30, d_model]

        last_state = x[:, -1, :]       # [B, d_model]

        out = self.out(last_state)     # [B, 10 * output_dim]

        return out.reshape(-1, 10, self.output_dim)

# %%
train_ds = load_train()
val_ds   = load_val()
# Out:
# Initial data manipulation done, computing sliding windows and building x and y tensors . . .
# 100%|██████████| 59518/59518 [00:51<00:00, 1151.94it/s]
# Built tensor lists
# Built full tensors
# torch.Size([3773409, 30, 4]) torch.Size([3773409, 10, 4])
# Initial data manipulation done, computing sliding windows and building x and y tensors . . .
# 100%|██████████| 12847/12847 [00:09<00:00, 1376.50it/s]
# Built tensor lists
# Built full tensors
# torch.Size([788039, 30, 4]) torch.Size([788039, 10, 4])

# %%
val_loader = torch.utils.data.DataLoader(
    val_ds, batch_size=64, shuffle=False
)
train_loader = torch.utils.data.DataLoader(
    train_ds, batch_size=64, shuffle=True
)

# %%
num_epochs = 15
model = TrajectoryTransformer30to10(
    input_dim=4,      # or 5 if MMSI is included
    output_dim=4,     # predicting same set of features
    d_model=128,
    nhead=4,
    num_layers=3,
    dim_feedforward=256
).to(device)

# %%
for epoch in range(num_epochs):
    model.train()

    train_mse  = 0.0
    train_rmse = 0.0
    train_mae  = 0.0

    for X, Y in train_loader:
        X, Y = X.to(device), Y.to(device)

        optimizer.zero_grad()
        pred = model(X)

        # Backprop loss = MSE
        loss = mse(pred, Y)
        loss.backward()
        optimizer.step()

        # --- METRICS ---
        mse_val  = loss.item()               # reuse computed loss!
        rmse_val = mse_val ** 0.5            # faster than sqrt() in torch
        mae_val  = mae(pred, Y).item()

        train_mse  += mse_val
        train_rmse += rmse_val
        train_mae  += mae_val

    # Averages
    train_mse  /= len(train_loader)
    train_rmse /= len(train_loader)
    train_mae  /= len(train_loader)

    print(
        f"Epoch {epoch}: "
        f"MSE={train_mse:.4f}, "
        f"RMSE={train_rmse:.4f}, "
        f"MAE={train_mae:.4f}"
    )

# %%
#Test different Models
configs = [
    {   
        "name": "Mini_Model",
        "model_kwargs": {
            "input_dim": 4,
            "output_dim": 4,
            "d_model": 128,
            "nhead": 4,
            "num_layers": 3,
            "dim_feedforward": 10,
            "dropout": 0.1,
        },
        "train_kwargs": {
            "num_epochs": 10,
            "learning_rate": 1e-3,
            "weight_decay": 1e-4,
        },
        "name": "A_small",
        "model_kwargs": {
            "input_dim": 4,
            "output_dim": 4,
            "d_model": 128,
            "nhead": 4,
            "num_layers": 3,
            "dim_feedforward": 512,
            "dropout": 0.1,
        },
        "train_kwargs": {
            "num_epochs": 40,
            "learning_rate": 1e-3,
            "weight_decay": 1e-4,
        },
    },
    {
        "name": "B_medium",
        "model_kwargs": {
            "input_dim": 4,
            "output_dim": 4,
            "d_model": 256,
            "nhead": 8,
            "num_layers": 3,
            "dim_feedforward": 1024,
            "dropout": 0.1,
        },
        "train_kwargs": {
            "num_epochs": 40,
            "learning_rate": 5e-4,
            "weight_decay": 1e-4,
        },
    },
    {
        "name": "C_deeper",
        "model_kwargs": {
            "input_dim": 4,
            "output_dim": 4,
            "d_model": 256,
            "nhead": 8,
            "num_layers": 4,
            "dim_feedforward": 1024,
            "dropout": 0.1,
        },
        "train_kwargs": {
            "num_epochs": 50,
            "learning_rate": 5e-4,
            "weight_decay": 1e-4,
        },
    },
    {
        "name": "C_deeper",
        "model_kwargs": {
            "input_dim": 4,
            "output_dim": 4,
            "d_model": 256,
            "nhead": 8,
            "num_layers": 4,
            "dim_feedforward": 1024,
            "dropout": 0.1,
        },
        "train_kwargs": {
            "num_epochs": 90,
            "learning_rate": 5e-4,
            "weight_decay": 1e-4,
        },
    },
]

# %%
#Run training model test

def train_one_config(config, train_loader, val_loader, device):
    name = config["name"]
    model_kwargs = config["model_kwargs"]
    train_kwargs = config["train_kwargs"]

    num_epochs   = train_kwargs["num_epochs"]
    learning_rate = train_kwargs["learning_rate"]
    weight_decay  = train_kwargs["weight_decay"]

    print(f"\n=== Training config: {name} ===")
    print("Model args:", model_kwargs)
    print("Train args:", train_kwargs)

    model = TrajectoryTransformer30to10(**model_kwargs).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

    history = {
        "train_mse": [],
        "train_rmse": [],
        "train_mae": [],
        "val_mse": [],
        "val_rmse": [],
        "val_mae": [],
    }

    for epoch in range(1, num_epochs + 1):
        # ---- TRAIN ----
        model.train()
        train_mse = 0.0
        train_mae = 0.0
        n_train   = 0

        for X, Y in train_loader:
            X, Y = X.to(device), Y.to(device)

            optimizer.zero_grad()
            preds = model(X)

            loss = criterion(preds, Y)
            loss.backward()
            optimizer.step()

            mse_batch = loss.item()
            mae_batch = torch.mean(torch.abs(preds - Y)).item()
            bs = X.size(0)

            train_mse += mse_batch * bs
            train_mae += mae_batch * bs
            n_train   += bs

        train_mse /= n_train
        train_rmse = math.sqrt(train_mse)
        train_mae /= n_train

        # ---- VALIDATION ----
        model.eval()
        val_mse = 0.0
        val_mae = 0.0
        n_val   = 0

        with torch.no_grad():
            for X_val, Y_val in val_loader:
                X_val, Y_val = X_val.to(device), Y_val.to(device)

                preds_val = model(X_val)
                loss_val  = criterion(preds_val, Y_val)

                mse_batch = loss_val.item()
                mae_batch = torch.mean(torch.abs(preds_val - Y_val)).item()
                bs = X_val.size(0)

                val_mse += mse_batch * bs
                val_mae += mae_batch * bs
                n_val   += bs

        val_mse /= n_val
        val_rmse = math.sqrt(val_mse)
        val_mae /= n_val

        history["train_mse"].append(train_mse)
        history["train_rmse"].append(train_rmse)
        history["train_mae"].append(train_mae)
        history["val_mse"].append(val_mse)
        history["val_rmse"].append(val_rmse)
        history["val_mae"].append(val_mae)

        print(
            f"Epoch {epoch:03d} | "
            f"Train MSE={train_mse:.4f}, RMSE={train_rmse:.4f}, MAE={train_mae:.4f} || "
            f"Val MSE={val_mse:.4f}, RMSE={val_rmse:.4f}, MAE={val_mae:.4f}"
        )

    # Rückgabe: letztes Val-RMSE + History + finales Modell
    final_val_rmse = history["val_rmse"][-1]
    return {
        "name": name,
        "config": config,
        "history": history,
        "final_val_rmse": final_val_rmse,
        "model": model,   
    }

# %%
results = []
best_result = None

for cfg in configs:
    result = train_one_config(cfg, train_loader, val_loader, device)
    results.append(result)

    if best_result is None or result["final_val_rmse"] < best_result["final_val_rmse"]:
        best_result = result

print("\n======================")
print("Best config:", best_result["name"])
print("Best final Val RMSE:", best_result["final_val_rmse"])
print("Best model args:", best_result["config"]["model_kwargs"])
print("Best train args:", best_result["config"]["train_kwargs"])
# Out:
# === Training config: A_small ===
# Model args: {'input_dim': 4, 'output_dim': 4, 'd_model': 128, 'nhead': 4, 'num_layers': 3, 'dim_feedforward': 512, 'dropout': 0.1}
# Train args: {'num_epochs': 40, 'learning_rate': 0.001, 'weight_decay': 0.0001}
# Epoch 001 | Train MSE=0.1953, RMSE=0.4419, MAE=0.2029 || Val MSE=0.1771, RMSE=0.4208, MAE=0.1789
# Epoch 002 | Train MSE=0.1838, RMSE=0.4288, MAE=0.1902 || Val MSE=0.1755, RMSE=0.4189, MAE=0.1791
# Epoch 003 | Train MSE=0.1808, RMSE=0.4252, MAE=0.1880 || Val MSE=0.1730, RMSE=0.4160, MAE=0.1803
# Epoch 004 | Train MSE=0.1794, RMSE=0.4235, MAE=0.1871 || Val MSE=0.1711, RMSE=0.4136, MAE=0.1818
# Epoch 005 | Train MSE=0.1787, RMSE=0.4227, MAE=0.1868 || Val MSE=0.1701, RMSE=0.4124, MAE=0.1746
# Epoch 006 | Train MSE=0.1780, RMSE=0.4219, MAE=0.1864 || Val MSE=0.1701, RMSE=0.4124, MAE=0.1704
# Epoch 007 | Train MSE=0.1775, RMSE=0.4214, MAE=0.1862 || Val MSE=0.1704, RMSE=0.4128, MAE=0.1792
# Epoch 008 | Train MSE=0.1773, RMSE=0.4211, MAE=0.1863 || Val MSE=0.1698, RMSE=0.4121, MAE=0.1750
# Epoch 009 | Train MSE=0.1772, RMSE=0.4209, MAE=0.1865 || Val MSE=0.1701, RMSE=0.4124, MAE=0.1729
# Epoch 010 | Train MSE=0.1768, RMSE=0.4204, MAE=0.1860 || Val MSE=0.1693, RMSE=0.4115, MAE=0.1727
# Epoch 011 | Train MSE=0.1769, RMSE=0.4206, MAE=0.1865 || Val MSE=0.1684, RMSE=0.4104, MAE=0.1755
# Epoch 012 | Train MSE=0.1765, RMSE=0.4201, MAE=0.1860 || Val MSE=0.1683, RMSE=0.4103, MAE=0.1765
# Epoch 013 | Train MSE=0.1763, RMSE=0.4199, MAE=0.1860 || Val MSE=0.1682, RMSE=0.4101, MAE=0.1748
# Epoch 014 | Train MSE=0.1763, RMSE=0.4198, MAE=0.1863 || Val MSE=0.1713, RMSE=0.4139, MAE=0.1774
# Epoch 015 | Train MSE=0.1759, RMSE=0.4194, MAE=0.1858 || Val MSE=0.1676, RMSE=0.4094, MAE=0.1720
# Epoch 016 | Train MSE=0.1762, RMSE=0.4198, MAE=0.1865 || Val MSE=0.1673, RMSE=0.4090, MAE=0.1745
# Epoch 017 | Train MSE=0.1760, RMSE=0.4195, MAE=0.1864 || Val MSE=0.1674, RMSE=0.4091, MAE=0.1681
# Epoch 018 | Train MSE=0.1758, RMSE=0.4193, MAE=0.1862 || Val MSE=0.1689, RMSE=0.4110, MAE=0.1718
# Epoch 019 | Train MSE=0.1757, RMSE=0.4192, MAE=0.1862 || Val MSE=0.1675, RMSE=0.4093, MAE=0.1735
# Epoch 020 | Train MSE=0.1761, RMSE=0.4196, MAE=0.1869 || Val MSE=0.1671, RMSE=0.4088, MAE=0.1705
# Epoch 021 | Train MSE=0.1755, RMSE=0.4190, MAE=0.1861 || Val MSE=0.1687, RMSE=0.4108, MAE=0.1761
# Epoch 022 | Train MSE=0.1760, RMSE=0.4196, MAE=0.1870 || Val MSE=0.1681, RMSE=0.4100, MAE=0.1700
# Epoch 023 | Train MSE=0.1756, RMSE=0.4190, MAE=0.1865 || Val MSE=0.1670, RMSE=0.4087, MAE=0.1726
# Epoch 024 | Train MSE=0.1760, RMSE=0.4195, MAE=0.1871 || Val MSE=0.1697, RMSE=0.4120, MAE=0.1786
# Epoch 025 | Train MSE=0.1766, RMSE=0.4202, MAE=0.1881 || Val MSE=0.1692, RMSE=0.4114, MAE=0.1764
# Epoch 026 | Train MSE=0.1761, RMSE=0.4197, MAE=0.1876 || Val MSE=0.1685, RMSE=0.4105, MAE=0.1798
# Epoch 027 | Train MSE=0.1759, RMSE=0.4194, MAE=0.1872 || Val MSE=0.1715, RMSE=0.4142, MAE=0.1839
# Epoch 028 | Train MSE=0.1761, RMSE=0.4196, MAE=0.1875 || Val MSE=0.1671, RMSE=0.4088, MAE=0.1674
# Epoch 029 | Train MSE=0.1759, RMSE=0.4194, MAE=0.1872 || Val MSE=0.1667, RMSE=0.4083, MAE=0.1707
# Epoch 030 | Train MSE=0.1760, RMSE=0.4196, MAE=0.1876 || Val MSE=0.1670, RMSE=0.4087, MAE=0.1738
# Epoch 031 | Train MSE=0.1757, RMSE=0.4192, MAE=0.1871 || Val MSE=0.1701, RMSE=0.4124, MAE=0.1776
# Epoch 032 | Train MSE=0.1761, RMSE=0.4196, MAE=0.1877 || Val MSE=0.1681, RMSE=0.4100, MAE=0.1749
# Epoch 033 | Train MSE=0.1758, RMSE=0.4193, MAE=0.1874 || Val MSE=0.1671, RMSE=0.4088, MAE=0.1748
# Epoch 034 | Train MSE=0.1763, RMSE=0.4199, MAE=0.1882 || Val MSE=0.1665, RMSE=0.4080, MAE=0.1749
# Epoch 035 | Train MSE=0.1762, RMSE=0.4198, MAE=0.1882 || Val MSE=0.1669, RMSE=0.4085, MAE=0.1703
# Epoch 036 | Train MSE=0.1767, RMSE=0.4203, MAE=0.1888 || Val MSE=0.1679, RMSE=0.4097, MAE=0.1694
# Epoch 037 | Train MSE=0.1759, RMSE=0.4195, MAE=0.1879 || Val MSE=0.1691, RMSE=0.4112, MAE=0.1765
# Epoch 038 | Train MSE=0.1756, RMSE=0.4190, MAE=0.1874 || Val MSE=0.1674, RMSE=0.4091, MAE=0.1703
# Epoch 039 | Train MSE=0.1759, RMSE=0.4194, MAE=0.1879 || Val MSE=0.1678, RMSE=0.4096, MAE=0.1758
# Epoch 040 | Train MSE=0.1759, RMSE=0.4193, MAE=0.1880 || Val MSE=0.1670, RMSE=0.4087, MAE=0.1692
#
# === Training config: B_medium ===
# Model args: {'input_dim': 4, 'output_dim': 4, 'd_model': 256, 'nhead': 8, 'num_layers': 3, 'dim_feedforward': 1024, 'dropout': 0.1}
# Train args: {'num_epochs': 40, 'learning_rate': 0.0005, 'weight_decay': 0.0001}
# Epoch 001 | Train MSE=0.1962, RMSE=0.4429, MAE=0.2116 || Val MSE=0.1789, RMSE=0.4230, MAE=0.1888
# Epoch 002 | Train MSE=0.1842, RMSE=0.4292, MAE=0.1952 || Val MSE=0.1721, RMSE=0.4148, MAE=0.1789
# Epoch 003 | Train MSE=0.1786, RMSE=0.4226, MAE=0.1881 || Val MSE=0.1690, RMSE=0.4111, MAE=0.1731
# Epoch 004 | Train MSE=0.1752, RMSE=0.4185, MAE=0.1843 || Val MSE=0.1654, RMSE=0.4066, MAE=0.1729
# Epoch 005 | Train MSE=0.1733, RMSE=0.4163, MAE=0.1824 || Val MSE=0.1650, RMSE=0.4062, MAE=0.1684
# Epoch 006 | Train MSE=0.1718, RMSE=0.4145, MAE=0.1808 || Val MSE=0.1668, RMSE=0.4085, MAE=0.1747
# Epoch 007 | Train MSE=0.1707, RMSE=0.4131, MAE=0.1796 || Val MSE=0.1638, RMSE=0.4047, MAE=0.1667
# Epoch 008 | Train MSE=0.1699, RMSE=0.4122, MAE=0.1789 || Val MSE=0.1630, RMSE=0.4037, MAE=0.1671
# Epoch 009 | Train MSE=0.1692, RMSE=0.4113, MAE=0.1781 || Val MSE=0.1628, RMSE=0.4035, MAE=0.1671
# Epoch 010 | Train MSE=0.1686, RMSE=0.4106, MAE=0.1775 || Val MSE=0.1628, RMSE=0.4035, MAE=0.1681
# Epoch 011 | Train MSE=0.1681, RMSE=0.4100, MAE=0.1771 || Val MSE=0.1622, RMSE=0.4028, MAE=0.1643
# Epoch 012 | Train MSE=0.1675, RMSE=0.4093, MAE=0.1764 || Val MSE=0.1619, RMSE=0.4023, MAE=0.1636
# Epoch 013 | Train MSE=0.1672, RMSE=0.4089, MAE=0.1761 || Val MSE=0.1623, RMSE=0.4029, MAE=0.1669
# Epoch 014 | Train MSE=0.1669, RMSE=0.4085, MAE=0.1759 || Val MSE=0.1612, RMSE=0.4015, MAE=0.1659
# Epoch 015 | Train MSE=0.1664, RMSE=0.4079, MAE=0.1753 || Val MSE=0.1607, RMSE=0.4009, MAE=0.1703
# Epoch 016 | Train MSE=0.1662, RMSE=0.4076, MAE=0.1752 || Val MSE=0.1606, RMSE=0.4007, MAE=0.1641
# Epoch 017 | Train MSE=0.1658, RMSE=0.4072, MAE=0.1748 || Val MSE=0.1614, RMSE=0.4017, MAE=0.1632
# Epoch 018 | Train MSE=0.1657, RMSE=0.4071, MAE=0.1748 || Val MSE=0.1604, RMSE=0.4005, MAE=0.1675
# Epoch 019 | Train MSE=0.1656, RMSE=0.4069, MAE=0.1747 || Val MSE=0.1602, RMSE=0.4002, MAE=0.1645
# Epoch 020 | Train MSE=0.1654, RMSE=0.4067, MAE=0.1746 || Val MSE=0.1601, RMSE=0.4001, MAE=0.1599
# Epoch 021 | Train MSE=0.1653, RMSE=0.4066, MAE=0.1746 || Val MSE=0.1600, RMSE=0.4000, MAE=0.1678
# Epoch 022 | Train MSE=0.1650, RMSE=0.4062, MAE=0.1741 || Val MSE=0.1605, RMSE=0.4007, MAE=0.1665
# Epoch 023 | Train MSE=0.1647, RMSE=0.4059, MAE=0.1738 || Val MSE=0.1592, RMSE=0.3989, MAE=0.1586
# Epoch 024 | Train MSE=0.1647, RMSE=0.4059, MAE=0.1739 || Val MSE=0.1591, RMSE=0.3988, MAE=0.1629
# Epoch 025 | Train MSE=0.1645, RMSE=0.4056, MAE=0.1736 || Val MSE=0.1589, RMSE=0.3986, MAE=0.1604
# Epoch 026 | Train MSE=0.1648, RMSE=0.4060, MAE=0.1744 || Val MSE=0.1594, RMSE=0.3993, MAE=0.1627
# Epoch 027 | Train MSE=0.1645, RMSE=0.4055, MAE=0.1739 || Val MSE=0.1590, RMSE=0.3988, MAE=0.1659

# %% [markdown]
# ### Plot Validation Loss

# %%
chosen = results[1]   # 0,1,2 depending on list of results
history = chosen["history"]
name = chosen["name"]

epochs = range(1, len(history["train_mse"]) + 1)

plt.figure(figsize=(8, 5))
plt.plot(epochs, history["train_mse"], 'r-', label='Train MSE')
plt.plot(epochs, history["val_mse"], 'b-', label='Val MSE')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.title(f'Training & Validation MSE — Model {name}')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Plot trajectory
# assume best_result is from search loop
net = results[1].to(device) #need to replace result that I want to plot
net.eval()



num_samples_to_plot = 5

for idx, (x, y) in enumerate(val_loader):
    if idx >= num_samples_to_plot:
        break

    x, y = x.to(device), y.to(device)

    with torch.no_grad():
        y_pred = net(x)      # Transformer: shape [B, 10, 4]

    # pick the first element in the batch
    x_np      = x[0].cpu().numpy()         # (30, 4)
    y_np      = y[0].cpu().numpy()         # (10, 4)
    y_pred_np = y_pred[0].cpu().numpy()    # (10, 4) already — no reshape needed

    plot_paths(x_np, y_np, y_pred_np, idx)
